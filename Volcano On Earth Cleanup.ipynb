# %%
import pandas as pd

# %%
vol_df = pd.read_csv('C://Users/Dave/Documents/Python Scripts/Volcanoes On Earth.csv')

vol_df.dtypes
# Out:
# Unnamed: 0                   int64
# Volcano_Name                object
# Volcano_Image               object
# Volcano_Type                object
# Country                     object
# Region                      object
# Subregion                   object
# epoch_period                object
# Last_Eruption               object
# Summit_and_Elevatiuon       object
# population_within_5km      float64
# population_within_10km     float64
# population_within_30km     float64
# population_within_100km    float64
# Latitude Coordinates       float64
# Longitude Coordinates      float64
# dtype: object

# %%
vol_df.head
# Out:
# <bound method NDFrame.head of       Unnamed: 0              Volcano_Name  \
# 0              0                       Abu
# 1              1                Acamarachi
# 2              2                Acatenango
# 3              3           Acigol-Nevsehir
# 4              4                     Adams
# ...          ...                       ...
# 2657        2657                  Zarechny
# 2658        2658                  Zenikame
# 2659        2659                   Zheltiy
# 2660        2660  Zhupanovskiye Vostriyaky
# 2661        2661                   Zikwala
#
#                                           Volcano_Image       Volcano_Type  \
# 0     https://volcano.si.edu/gallery/photos/GVP-0895...          Shield(s)
# 1     https://volcano.si.edu/gallery/photos/GVP-0688...      Stratovolcano
# 2     https://volcano.si.edu/gallery/photos/GVP-0788...  Stratovolcano(es)
# 3     https://volcano.si.edu/includes/images/noimage...            Caldera
# ...

# %%
vol_df[['Summit_and_Elevatiuon','Elevation']] = vol_df['Summit_and_Elevatiuon'].str.split(', ', expand = True)
# Out:
#                   Volcano_Name  \
# 0                          Abu
# 1                   Acamarachi
# 2                   Acatenango
# 3              Acigol-Nevsehir
# 4                        Adams
# ...                        ...
# 2657                  Zarechny
# 2658                  Zenikame
# 2659                   Zheltiy
# 2660  Zhupanovskiye Vostriyaky
# 2661                   Zikwala
#
#                                           Volcano_Image       Volcano_Type  \
# 0     https://volcano.si.edu/gallery/photos/GVP-0895...          Shield(s)
# 1     https://volcano.si.edu/gallery/photos/GVP-0688...      Stratovolcano
# 2     https://volcano.si.edu/gallery/photos/GVP-0788...  Stratovolcano(es)
# 3     https://volcano.si.edu/includes/images/noimage...            Caldera
# 4     https://volcano.si.edu/gallery/photos/GVP-0281...      Stratovolcano
# ...                                                 ...                ...
# ...

# %%
vol_df = vol_df.rename(columns={"Summit_and_Elevatiuon": "Summit"})

# %%
vol_df = vol_df.drop(columns=["Unnamed: 0"])

# %%
vol_df['Volcano_Type'] = vol_df['Volcano_Type'].str.replace('(s)','')
vol_df['Volcano_Type'] = vol_df['Volcano_Type'].str.replace('(es)','')

# %%
vol_df
# Out:
#                   Volcano_Name  \
# 0                          Abu
# 1                   Acamarachi
# 2                   Acatenango
# 3              Acigol-Nevsehir
# 4                        Adams
# ...                        ...
# 2657                  Zarechny
# 2658                  Zenikame
# 2659                   Zheltiy
# 2660  Zhupanovskiye Vostriyaky
# 2661                   Zikwala
#
#                                           Volcano_Image   Volcano_Type  \
# 0     https://volcano.si.edu/gallery/photos/GVP-0895...         Shield
# 1     https://volcano.si.edu/gallery/photos/GVP-0688...  Stratovolcano
# 2     https://volcano.si.edu/gallery/photos/GVP-0788...  Stratovolcano
# 3     https://volcano.si.edu/includes/images/noimage...        Caldera
# 4     https://volcano.si.edu/gallery/photos/GVP-0281...  Stratovolcano
# ...                                                 ...            ...
# 2657  https://volcano.si.edu/includes/images/noimage...        Caldera
# ...
